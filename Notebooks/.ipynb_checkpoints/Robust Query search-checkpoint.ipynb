# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

# %% [markdown]
# # Client_Id and Client_Secret

# %%
client_id = 'a91b43299c1640f0aa948cec94a6f6fe'
client_secret = 'dcb87c21bfaa4644b7fff077bb29c129'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expires = True
    
    client_id = None
    client_secret = None
    token_url = " https://accounts.spotify.com/api/token"
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns: a Base 64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client_Id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
        
    def get_token_header(self):
        client_creds_b64 = self.get_client_credentials()
        
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
        
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }

    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_header()
        req = requests.post(token_url, data=token_data, headers=token_headers)
        if req.status_code not in range(200,299):
             raise Exception("could not Authenticate the client")
        
        data = req.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expires = expires < now
        return True
    
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires<now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
     
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization" : f"Bearer {access_token}" 
        }
        return headers
    
    def get_resource(self,lookup_id,resource_type = 'albums',version='v1'):
        endpoint = f" https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

        
            
    def get_album(self,_id):
        return self.get_resource(_id,resource_type='albums')

    def get_artists(self,_id):
        return self.get_resource(_id,resource_type='artists')
        
    
    def search(self, query, search_type = "artist"):
        headers = self.get_resource_header()
        endpoint = " https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        look_url = f"{endpoint}?{data}"
        print(look_url)
        r = requests.get(look_url, headers = headers)
        if r.status_code not in range(200, 299):
            return {}
        
        return r.json()

# %%
spotify.get_access_token()
# Out:
# 'BQA39xFqXIGuxo6_BvHGQm7NBH0E_yTTCktTD11XjKebf9Rhtzy4WdgMywCAoAtb8H5s1IhcCxCGLDnsQtg'

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search("Starboy",search_type="Track")
# Out:
#  https://api.spotify.com/v1/search?q=Starboy&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Starboy&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#      'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#      'id': '2ODvWsOgouMbaA5xf0RkJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11600976'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#     'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#     'id': '7MXVkk9YMctZqd1Srtv4MB',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 85,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4rGQxBDZ4hHCKePXaYOTSB'},
#      'href': 'https://api.spotify.com/v1/albums/4rGQxBDZ4hHCKePXaYOTSB',
#      'id': '4rGQxBDZ4hHCKePXaYOTSB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2148749eb6478e176b3f93c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2148749eb6478e176b3f93c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2148749eb6478e176b3f93c',
#        'width': 64}],
#      'name': 'Starboy (Kygo Remix)',
#      'release_date': '2016-11-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4rGQxBDZ4hHCKePXaYOTSB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#       'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#       'id': '23fqKkggKUBHNkbKtXEls4',
#       'name': 'Kygo',
#       'type': 'artist',
#       'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244720,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11601353'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LJFgCd9wU2VptHEwz2Wl3'},
#     'href': 'https://api.spotify.com/v1/tracks/6LJFgCd9wU2VptHEwz2Wl3',
#     'id': '6LJFgCd9wU2VptHEwz2Wl3',
#     'is_local': False,
#     'name': 'Starboy - Kygo Remix',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6LJFgCd9wU2VptHEwz2Wl3'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5pJAx43ygdhq0uKb0MABEo'},
#      'href': 'https://api.spotify.com/v1/albums/5pJAx43ygdhq0uKb0MABEo',
#      'id': '5pJAx43ygdhq0uKb0MABEo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27378666f5f8696c188ac93a76e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0278666f5f8696c188ac93a76e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485178666f5f8696c188ac93a76e',
#        'width': 64}],
#      'name': 'Soco (feat. Wizkid, Ceeza Milli, Spotless & Terri)',
#      'release_date': '2018-02-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5pJAx43ygdhq0uKb0MABEo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/11b21KVATwG7LgLPiD3a1A'},
#       'href': 'https://api.spotify.com/v1/artists/11b21KVATwG7LgLPiD3a1A',
#       'id': '11b21KVATwG7LgLPiD3a1A',
#       'name': 'Ceeza Milli',
#       'type': 'artist',
#       'uri': 'spotify:artist:11b21KVATwG7LgLPiD3a1A'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7zd8O0lGS5sHftyvnhtWD1'},
#       'href': 'https://api.spotify.com/v1/artists/7zd8O0lGS5sHftyvnhtWD1',
#       'id': '7zd8O0lGS5sHftyvnhtWD1',
#       'name': 'Spotless',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zd8O0lGS5sHftyvnhtWD1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6h3iqdnfBKV2jRhUJz0oto'},
#       'href': 'https://api.spotify.com/v1/artists/6h3iqdnfBKV2jRhUJz0oto',
#       'id': '6h3iqdnfBKV2jRhUJz0oto',
#       'name': 'Terri',
#       'type': 'artist',
#       'uri': 'spotify:artist:6h3iqdnfBKV2jRhUJz0oto'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 255608,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1184573'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KpBtWSI9dlv0RjtzvF1BD'},
#     'href': 'https://api.spotify.com/v1/tracks/1KpBtWSI9dlv0RjtzvF1BD',
#     'id': '1KpBtWSI9dlv0RjtzvF1BD',
#     'is_local': False,
#     'name': 'Soco (feat. Wizkid, Ceeza Milli, Spotless & Terri)',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66e9251c3be09d5bdfaeca9a4e1dafbd68f08440?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1KpBtWSI9dlv0RjtzvF1BD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hyAYqBdxyramm4W9TB7R0'},
#        'href': 'https://api.spotify.com/v1/artists/6hyAYqBdxyramm4W9TB7R0',
#        'id': '6hyAYqBdxyramm4W9TB7R0',
#        'name': 'The Animal In Me',
#        'type': 'artist',
#        'uri': 'spotify:artist:6hyAYqBdxyramm4W9TB7R0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5raf9Agi3ferPfy54ucXLH'},
#      'href': 'https://api.spotify.com/v1/albums/5raf9Agi3ferPfy54ucXLH',
#      'id': '5raf9Agi3ferPfy54ucXLH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736339c72394e2568c811ebccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026339c72394e2568c811ebccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516339c72394e2568c811ebccd',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2017-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5raf9Agi3ferPfy54ucXLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hyAYqBdxyramm4W9TB7R0'},
#       'href': 'https://api.spotify.com/v1/artists/6hyAYqBdxyramm4W9TB7R0',
#       'id': '6hyAYqBdxyramm4W9TB7R0',
#       'name': 'The Animal In Me',
#       'type': 'artist',
#       'uri': 'spotify:artist:6hyAYqBdxyramm4W9TB7R0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 246362,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ22B1763574'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4LceuFIJXzhCJ9iJsYmf0f'},
#     'href': 'https://api.spotify.com/v1/tracks/4LceuFIJXzhCJ9iJsYmf0f',
#     'id': '4LceuFIJXzhCJ9iJsYmf0f',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9634cb73bfade10fb85590eab97be2c235e1c4a7?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4LceuFIJXzhCJ9iJsYmf0f'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nhLODdncnkg3rVlzva3YY'},
#      'href': 'https://api.spotify.com/v1/albums/5nhLODdncnkg3rVlzva3YY',
#      'id': '5nhLODdncnkg3rVlzva3YY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b24260bc2bc0fe6ffd8d645',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b24260bc2bc0fe6ffd8d645',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b24260bc2bc0fe6ffd8d645',
#        'width': 64}],
#      'name': 'SoundMan Vol. 1',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5nhLODdncnkg3rVlzva3YY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2oZcMYiKpjaA2Et5mU3RPP'},
#       'href': 'https://api.spotify.com/v1/artists/2oZcMYiKpjaA2Et5mU3RPP',
#       'id': '2oZcMYiKpjaA2Et5mU3RPP',
#       'name': 'Chronixx',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oZcMYiKpjaA2Et5mU3RPP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 198678,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1286547'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6eHqU8ntHGzddACoxlfDX0'},
#     'href': 'https://api.spotify.com/v1/tracks/6eHqU8ntHGzddACoxlfDX0',
#     'id': '6eHqU8ntHGzddACoxlfDX0',
#     'is_local': False,
#     'name': 'Jam',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/97508c8b7ba67965875a8937694a4feebb41b390?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6eHqU8ntHGzddACoxlfDX0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nhLODdncnkg3rVlzva3YY'},
#      'href': 'https://api.spotify.com/v1/albums/5nhLODdncnkg3rVlzva3YY',
#      'id': '5nhLODdncnkg3rVlzva3YY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b24260bc2bc0fe6ffd8d645',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b24260bc2bc0fe6ffd8d645',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b24260bc2bc0fe6ffd8d645',
#        'width': 64}],
#      'name': 'SoundMan Vol. 1',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5nhLODdncnkg3rVlzva3YY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4on7a4BKixLl1rSlEcaY8Y'},
#       'href': 'https://api.spotify.com/v1/artists/4on7a4BKixLl1rSlEcaY8Y',
#       'id': '4on7a4BKixLl1rSlEcaY8Y',
#       'name': 'Blaq Jerzee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4on7a4BKixLl1rSlEcaY8Y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 228118,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1286548'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0cQiqNmTIENnlviVwS4yos'},
#     'href': 'https://api.spotify.com/v1/tracks/0cQiqNmTIENnlviVwS4yos',
#     'id': '0cQiqNmTIENnlviVwS4yos',
#     'is_local': False,
#     'name': 'Blow',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9aa58c3202daf170f2cf1e4d3ca635c94d909e69?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0cQiqNmTIENnlviVwS4yos'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42PbLkrI8H7k1kqOU3wnmN'},
#        'href': 'https://api.spotify.com/v1/artists/42PbLkrI8H7k1kqOU3wnmN',
#        'id': '42PbLkrI8H7k1kqOU3wnmN',
#        'name': 'TyBuckz',
#        'type': 'artist',
#        'uri': 'spotify:artist:42PbLkrI8H7k1kqOU3wnmN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6NPfRhMgn6KIH6PePIEX2Y'},
#      'href': 'https://api.spotify.com/v1/albums/6NPfRhMgn6KIH6PePIEX2Y',
#      'id': '6NPfRhMgn6KIH6PePIEX2Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739525683bb621aabf399d6ac8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029525683bb621aabf399d6ac8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519525683bb621aabf399d6ac8',
#        'width': 64}],
#      'name': 'Starboy Pack',
#      'release_date': '2020-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6NPfRhMgn6KIH6PePIEX2Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42PbLkrI8H7k1kqOU3wnmN'},
#       'href': 'https://api.spotify.com/v1/artists/42PbLkrI8H7k1kqOU3wnmN',
#       'id': '42PbLkrI8H7k1kqOU3wnmN',
#       'name': 'TyBuckz',
#       'type': 'artist',
#       'uri': 'spotify:artist:42PbLkrI8H7k1kqOU3wnmN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 107728,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZDA62032950'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6kC29mbkeRPP0odWTEJ4x4'},
#     'href': 'https://api.spotify.com/v1/tracks/6kC29mbkeRPP0odWTEJ4x4',
#     'id': '6kC29mbkeRPP0odWTEJ4x4',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/05644a4a77886cd13a1483c8bc4c1cb40d918cf9?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6kC29mbkeRPP0odWTEJ4x4'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KwmxIhSe9UTSEF37kwngR'},
#        'href': 'https://api.spotify.com/v1/artists/3KwmxIhSe9UTSEF37kwngR',
#        'id': '3KwmxIhSe9UTSEF37kwngR',
#        'name': 'SHAED',
#        'type': 'artist',
#        'uri': 'spotify:artist:3KwmxIhSe9UTSEF37kwngR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7422NfmOW8GffdVQNbM90S'},
#      'href': 'https://api.spotify.com/v1/albums/7422NfmOW8GffdVQNbM90S',
#      'id': '7422NfmOW8GffdVQNbM90S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273369a5fb7be1d112246988433',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02369a5fb7be1d112246988433',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851369a5fb7be1d112246988433',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2016-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7422NfmOW8GffdVQNbM90S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KwmxIhSe9UTSEF37kwngR'},
#       'href': 'https://api.spotify.com/v1/artists/3KwmxIhSe9UTSEF37kwngR',
#       'id': '3KwmxIhSe9UTSEF37kwngR',
#       'name': 'SHAED',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KwmxIhSe9UTSEF37kwngR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211173,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ47A1600208'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7FxWJX9m6V4d9lYZ5vogqW'},
#     'href': 'https://api.spotify.com/v1/tracks/7FxWJX9m6V4d9lYZ5vogqW',
#     'id': '7FxWJX9m6V4d9lYZ5vogqW',
#     'is_local': False,
#     'name': 'Starboy - Recorded at Spotify Studios NYC',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7FxWJX9m6V4d9lYZ5vogqW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DRnjvzNP8pk868AvG5Kpd'},
#        'href': 'https://api.spotify.com/v1/artists/4DRnjvzNP8pk868AvG5Kpd',
#        'id': '4DRnjvzNP8pk868AvG5Kpd',
#        'name': 'RPM (Relaxing Piano Music)',
#        'type': 'artist',
#        'uri': 'spotify:artist:4DRnjvzNP8pk868AvG5Kpd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ZE6huGctIo5v1wWRjxAVg'},
#      'href': 'https://api.spotify.com/v1/albums/4ZE6huGctIo5v1wWRjxAVg',
#      'id': '4ZE6huGctIo5v1wWRjxAVg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fb6fdd725d54fe511f7f34fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fb6fdd725d54fe511f7f34fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fb6fdd725d54fe511f7f34fb',
#        'width': 64}],
#      'name': 'RPM (Relaxing Piano Music)',
#      'release_date': '2019-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4ZE6huGctIo5v1wWRjxAVg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DRnjvzNP8pk868AvG5Kpd'},
#       'href': 'https://api.spotify.com/v1/artists/4DRnjvzNP8pk868AvG5Kpd',
#       'id': '4DRnjvzNP8pk868AvG5Kpd',
#       'name': 'RPM (Relaxing Piano Music)',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DRnjvzNP8pk868AvG5Kpd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 239693,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEBGA1700089'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3IZPbpm7bAcgiE8lwoyCEB'},
#     'href': 'https://api.spotify.com/v1/tracks/3IZPbpm7bAcgiE8lwoyCEB',
#     'id': '3IZPbpm7bAcgiE8lwoyCEB',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/54e5baa5db6ea359f498dffa2dfa6e526d4b0ab6?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3IZPbpm7bAcgiE8lwoyCEB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2hCyuqpTXNKYkEXyABXE9j'},
#      'href': 'https://api.spotify.com/v1/albums/2hCyuqpTXNKYkEXyABXE9j',
#      'id': '2hCyuqpTXNKYkEXyABXE9j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734cfcc7a80d7a8da378f968b0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024cfcc7a80d7a8da378f968b0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514cfcc7a80d7a8da378f968b0',
#        'width': 64}],
#      'name': 'Fake Love (feat. Duncan Mighty & WizKid)',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2hCyuqpTXNKYkEXyABXE9j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5N47dnIfPuGH8kIHpf8gZK'},
#       'href': 'https://api.spotify.com/v1/artists/5N47dnIfPuGH8kIHpf8gZK',
#       'id': '5N47dnIfPuGH8kIHpf8gZK',
#       'name': 'Duncan Mighty',
#       'type': 'artist',
#       'uri': 'spotify:artist:5N47dnIfPuGH8kIHpf8gZK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 246792,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1195872'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1zikqHEDuxRMnhYxSR41lR'},
#     'href': 'https://api.spotify.com/v1/tracks/1zikqHEDuxRMnhYxSR41lR',
#     'id': '1zikqHEDuxRMnhYxSR41lR',
#     'is_local': False,
#     'name': 'Fake Love (feat. Duncan Mighty & WizKid)',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a253a36937d65e5d48e37f2ee123ce225fd1d3ca?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1zikqHEDuxRMnhYxSR41lR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nhLODdncnkg3rVlzva3YY'},
#      'href': 'https://api.spotify.com/v1/albums/5nhLODdncnkg3rVlzva3YY',
#      'id': '5nhLODdncnkg3rVlzva3YY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b24260bc2bc0fe6ffd8d645',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b24260bc2bc0fe6ffd8d645',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b24260bc2bc0fe6ffd8d645',
#        'width': 64}],
#      'name': 'SoundMan Vol. 1',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5nhLODdncnkg3rVlzva3YY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/48XO5sXDsZ0NgyVmGT5qxW'},
#       'href': 'https://api.spotify.com/v1/artists/48XO5sXDsZ0NgyVmGT5qxW',
#       'id': '48XO5sXDsZ0NgyVmGT5qxW',
#       'name': 'London',
#       'type': 'artist',
#       'uri': 'spotify:artist:48XO5sXDsZ0NgyVmGT5qxW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 178775,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1286551'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2g59YEtG3OZq3lp4eDj97p'},
#     'href': 'https://api.spotify.com/v1/tracks/2g59YEtG3OZq3lp4eDj97p',
#     'id': '2g59YEtG3OZq3lp4eDj97p',
#     'is_local': False,
# ...
#      'href': 'https://api.spotify.com/v1/albums/5Bh0yujzOhMqly3ONkprWR',
#      'id': '5Bh0yujzOhMqly3ONkprWR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d4129a6795ffb602cd79ffd2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d4129a6795ffb602cd79ffd2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d4129a6795ffb602cd79ffd2',
#        'width': 64}],
#      'name': 'Starboy (Acoustic)',
#      'release_date': '2016-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5Bh0yujzOhMqly3ONkprWR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4yZSvg16XY22sxvZzKfw'},
#       'href': 'https://api.spotify.com/v1/artists/7n4yZSvg16XY22sxvZzKfw',
#       'id': '7n4yZSvg16XY22sxvZzKfw',
#       'name': 'Simon Samaeng',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n4yZSvg16XY22sxvZzKfw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 225790,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1600514'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2QoyYV4YAuw9T9UgsDoam2'},
#     'href': 'https://api.spotify.com/v1/tracks/2QoyYV4YAuw9T9UgsDoam2',
#     'id': '2QoyYV4YAuw9T9UgsDoam2',
#     'is_local': False,
#     'name': 'Starboy - Acoustic',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/670ed08513d8d23a5756745b58be00781a49361b?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2QoyYV4YAuw9T9UgsDoam2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#        'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#        'id': '3CQCQz0XwZooCdtGgwtcR7',
#        'name': 'Starboy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5nhLODdncnkg3rVlzva3YY'},
#      'href': 'https://api.spotify.com/v1/albums/5nhLODdncnkg3rVlzva3YY',
#      'id': '5nhLODdncnkg3rVlzva3YY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b24260bc2bc0fe6ffd8d645',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b24260bc2bc0fe6ffd8d645',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b24260bc2bc0fe6ffd8d645',
#        'width': 64}],
#      'name': 'SoundMan Vol. 1',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5nhLODdncnkg3rVlzva3YY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQCQz0XwZooCdtGgwtcR7'},
#       'href': 'https://api.spotify.com/v1/artists/3CQCQz0XwZooCdtGgwtcR7',
#       'id': '3CQCQz0XwZooCdtGgwtcR7',
#       'name': 'Starboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQCQz0XwZooCdtGgwtcR7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tVQdUvClmAT7URs9V3rsp'},
#       'href': 'https://api.spotify.com/v1/artists/3tVQdUvClmAT7URs9V3rsp',
#       'id': '3tVQdUvClmAT7URs9V3rsp',
#       'name': 'WizKid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tVQdUvClmAT7URs9V3rsp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/64oW4P0vsDhlorOxZKQi6a'},
#       'href': 'https://api.spotify.com/v1/artists/64oW4P0vsDhlorOxZKQi6a',
#       'id': '64oW4P0vsDhlorOxZKQi6a',
#       'name': 'DJ Tunez',
#       'type': 'artist',
#       'uri': 'spotify:artist:64oW4P0vsDhlorOxZKQi6a'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 198656,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUYG1286549'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4T5Wm2tAqZ4RZs8z0Hn7Wg'},
#     'href': 'https://api.spotify.com/v1/tracks/4T5Wm2tAqZ4RZs8z0Hn7Wg',
#     'id': '4T5Wm2tAqZ4RZs8z0Hn7Wg',
#     'is_local': False,
#     'name': 'Cover Me',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1540dee494bd7f13365dafd6a101b45e55e8231e?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4T5Wm2tAqZ4RZs8z0Hn7Wg'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvOGQ4uW2viBHMmkyl3C2'},
#        'href': 'https://api.spotify.com/v1/artists/5zvOGQ4uW2viBHMmkyl3C2',
#        'id': '5zvOGQ4uW2viBHMmkyl3C2',
#        'name': 'Kyle Edwards',
#        'type': 'artist',
#        'uri': 'spotify:artist:5zvOGQ4uW2viBHMmkyl3C2'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GrHfxMFCXCdIhN9DrAxjK'},
#        'href': 'https://api.spotify.com/v1/artists/6GrHfxMFCXCdIhN9DrAxjK',
#        'id': '6GrHfxMFCXCdIhN9DrAxjK',
#        'name': 'DJ Smallz 732',
#        'type': 'artist',
#        'uri': 'spotify:artist:6GrHfxMFCXCdIhN9DrAxjK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0xP9xRkTvR4KDK7J5UTm5V'},
#      'href': 'https://api.spotify.com/v1/albums/0xP9xRkTvR4KDK7J5UTm5V',
#      'id': '0xP9xRkTvR4KDK7J5UTm5V',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d59abd98209f2c4e73a6267c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d59abd98209f2c4e73a6267c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d59abd98209f2c4e73a6267c',
#        'width': 64}],
#      'name': 'Starboy (Harder Better Faster Stronger Jersey Club)',
#      'release_date': '2016-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0xP9xRkTvR4KDK7J5UTm5V'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zvOGQ4uW2viBHMmkyl3C2'},
#       'href': 'https://api.spotify.com/v1/artists/5zvOGQ4uW2viBHMmkyl3C2',
#       'id': '5zvOGQ4uW2viBHMmkyl3C2',
#       'name': 'Kyle Edwards',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zvOGQ4uW2viBHMmkyl3C2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GrHfxMFCXCdIhN9DrAxjK'},
#       'href': 'https://api.spotify.com/v1/artists/6GrHfxMFCXCdIhN9DrAxjK',
#       'id': '6GrHfxMFCXCdIhN9DrAxjK',
#       'name': 'DJ Smallz 732',
#       'type': 'artist',
#       'uri': 'spotify:artist:6GrHfxMFCXCdIhN9DrAxjK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 82416,
#     'explicit': False,
#     'external_ids': {'isrc': 'USDHM1624733'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/098BiO1QQzH1tMgSRS8eCz'},
#     'href': 'https://api.spotify.com/v1/tracks/098BiO1QQzH1tMgSRS8eCz',
#     'id': '098BiO1QQzH1tMgSRS8eCz',
#     'is_local': False,
#     'name': 'Starboy (Harder Better Faster Stronger Jersey Club)',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a68cd9f76ee17b9a3f671c3ab25931bf7f124411?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:098BiO1QQzH1tMgSRS8eCz'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00190FC20vIUv0wXpeTf8S'},
#        'href': 'https://api.spotify.com/v1/artists/00190FC20vIUv0wXpeTf8S',
#        'id': '00190FC20vIUv0wXpeTf8S',
#        'name': 'KRNFX',
#        'type': 'artist',
#        'uri': 'spotify:artist:00190FC20vIUv0wXpeTf8S'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/05iZ9CNkJp5TURl0ET55hL'},
#      'href': 'https://api.spotify.com/v1/albums/05iZ9CNkJp5TURl0ET55hL',
#      'id': '05iZ9CNkJp5TURl0ET55hL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d2464c57ffc089c24736c856',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d2464c57ffc089c24736c856',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d2464c57ffc089c24736c856',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:05iZ9CNkJp5TURl0ET55hL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00190FC20vIUv0wXpeTf8S'},
#       'href': 'https://api.spotify.com/v1/artists/00190FC20vIUv0wXpeTf8S',
#       'id': '00190FC20vIUv0wXpeTf8S',
#       'name': 'KRNFX',
#       'type': 'artist',
#       'uri': 'spotify:artist:00190FC20vIUv0wXpeTf8S'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204232,
#     'explicit': True,
#     'external_ids': {'isrc': 'ushm91629466'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2xW3EQxFuuFVgU6RCeZGe9'},
#     'href': 'https://api.spotify.com/v1/tracks/2xW3EQxFuuFVgU6RCeZGe9',
#     'id': '2xW3EQxFuuFVgU6RCeZGe9',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e65ebd781c169e9bddc2c514481a8defdc3a7092?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2xW3EQxFuuFVgU6RCeZGe9'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Starboy&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 1719}}

# %%
spotify.get_artists(_id="1Xyo4u8uXC1ZmMpatF05PJ")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  'followers': {'href': None, 'total': 20224071},
#  'genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#  'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/d9a875c37277c35b94c60c00d2cd256db098505d',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/91c55730d3f156894d744d560afe441af3f5a228',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/19393c56208fe6c312384879c11ff3da463f1304',
#    'width': 160}],
#  'name': 'The Weeknd',
#  'popularity': 98,
#  'type': 'artist',
#  'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}

# %%
spotify.get_album(_id="2ODvWsOgouMbaA5xf0RkJe")
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#    'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#    'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#    'name': 'The Weeknd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#  'available_markets': ['AD',
#   'AE',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'SA',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
#   'ZA'],
#  'copyrights': [{'text': '© 2016 The Weeknd XO, Inc., Manufactured and Marketed by Republic Records, a Division of UMG Recordings, Inc.',
#    'type': 'C'},
#   {'text': '℗ 2016 The Weeknd XO, Inc., Manufactured and Marketed by Republic Records, a Division of UMG Recordings, Inc.',
#    'type': 'P'}],
#  'external_ids': {'upc': '00602557333664'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#  'id': '2ODvWsOgouMbaA5xf0RkJe',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#    'width': 64}],
#  'label': 'Universal Republic Records',
#  'name': 'Starboy',
#  'popularity': 85,
#  'release_date': '2016-11-25',
#  'release_date_precision': 'day',
#  'total_tracks': 18,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230453,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#     'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#     'id': '7MXVkk9YMctZqd1Srtv4MB',
#     'is_local': False,
#     'name': 'Starboy',
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 249213,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4F7A0DXBrmUAkp32uenhZt'},
#     'href': 'https://api.spotify.com/v1/tracks/4F7A0DXBrmUAkp32uenhZt',
#     'id': '4F7A0DXBrmUAkp32uenhZt',
#     'is_local': False,
#     'name': 'Party Monster',
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4F7A0DXBrmUAkp32uenhZt'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 220306,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oeaIftdpT3JuZLcCkKmVE'},
#     'href': 'https://api.spotify.com/v1/tracks/4oeaIftdpT3JuZLcCkKmVE',
#     'id': '4oeaIftdpT3JuZLcCkKmVE',
#     'is_local': False,
#     'name': 'False Alarm',
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4oeaIftdpT3JuZLcCkKmVE'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 218880,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/37F0uwRSrdzkBiuj0D5UHI'},
#     'href': 'https://api.spotify.com/v1/tracks/37F0uwRSrdzkBiuj0D5UHI',
#     'id': '37F0uwRSrdzkBiuj0D5UHI',
#     'is_local': False,
#     'name': 'Reminder',
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:37F0uwRSrdzkBiuj0D5UHI'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232880,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/36YCdzT57us0LhDmCYtrNE'},
#     'href': 'https://api.spotify.com/v1/tracks/36YCdzT57us0LhDmCYtrNE',
#     'id': '36YCdzT57us0LhDmCYtrNE',
#     'is_local': False,
#     'name': 'Rockin’',
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:36YCdzT57us0LhDmCYtrNE'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 265600,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00NAQYOP4AmWR549nnYJZu'},
#     'href': 'https://api.spotify.com/v1/tracks/00NAQYOP4AmWR549nnYJZu',
#     'id': '00NAQYOP4AmWR549nnYJZu',
#     'is_local': False,
#     'name': 'Secrets',
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:00NAQYOP4AmWR549nnYJZu'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 206013,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1oGdVdYjeQvojGKDddxLQQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1oGdVdYjeQvojGKDddxLQQ',
#     'id': '1oGdVdYjeQvojGKDddxLQQ',
#     'is_local': False,
#     'name': 'True Colors',
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1oGdVdYjeQvojGKDddxLQQ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#       'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#       'id': '00FQb4jTyendYWaN8pK0wa',
#       'name': 'Lana Del Rey',
#       'type': 'artist',
#       'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 111640,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EDijkJdHBZZ0GwJ12iTAj'},
#     'href': 'https://api.spotify.com/v1/tracks/4EDijkJdHBZZ0GwJ12iTAj',
#     'id': '4EDijkJdHBZZ0GwJ12iTAj',
#     'is_local': False,
#     'name': 'Stargirl Interlude',
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4EDijkJdHBZZ0GwJ12iTAj'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#       'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#       'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#       'name': 'Kendrick Lamar',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231360,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4h90qkbnW1Qq6pBhoPvwko'},
#     'href': 'https://api.spotify.com/v1/tracks/4h90qkbnW1Qq6pBhoPvwko',
#     'id': '4h90qkbnW1Qq6pBhoPvwko',
#     'is_local': False,
#     'name': 'Sidewalks',
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4h90qkbnW1Qq6pBhoPvwko'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237573,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mU5iXHeLgbR94siF7p1sY'},
#     'href': 'https://api.spotify.com/v1/tracks/4mU5iXHeLgbR94siF7p1sY',
#     'id': '4mU5iXHeLgbR94siF7p1sY',
#     'is_local': False,
#     'name': 'Six Feet Under',
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4mU5iXHeLgbR94siF7p1sY'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 223293,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/27BgDmciSjoxTG0almHTpZ'},
#     'href': 'https://api.spotify.com/v1/tracks/27BgDmciSjoxTG0almHTpZ',
#     'id': '27BgDmciSjoxTG0almHTpZ',
#     'is_local': False,
#     'name': 'Love To Lay',
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:27BgDmciSjoxTG0almHTpZ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 220173,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ifooM33X1iBxVYyOkSbXW'},
#     'href': 'https://api.spotify.com/v1/tracks/0ifooM33X1iBxVYyOkSbXW',
#     'id': '0ifooM33X1iBxVYyOkSbXW',
#     'is_local': False,
#     'name': 'A Lonely Night',
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:0ifooM33X1iBxVYyOkSbXW'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197653,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6pDVjCUA3B1vg9waKutAsv'},
#     'href': 'https://api.spotify.com/v1/tracks/6pDVjCUA3B1vg9waKutAsv',
#     'id': '6pDVjCUA3B1vg9waKutAsv',
#     'is_local': False,
#     'name': 'Attention',
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6pDVjCUA3B1vg9waKutAsv'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221920,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15k2nBQJ0teDmPZHrOXL2N'},
#     'href': 'https://api.spotify.com/v1/tracks/15k2nBQJ0teDmPZHrOXL2N',
#     'id': '15k2nBQJ0teDmPZHrOXL2N',
#     'is_local': False,
#     'name': 'Ordinary Life',
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:15k2nBQJ0teDmPZHrOXL2N'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 198653,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57qiTKh8bVX0VtfUNTQqhw'},
#     'href': 'https://api.spotify.com/v1/tracks/57qiTKh8bVX0VtfUNTQqhw',
#     'id': '57qiTKh8bVX0VtfUNTQqhw',
#     'is_local': False,
#     'name': 'Nothing Without You',
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:57qiTKh8bVX0VtfUNTQqhw'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 321026,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0NWqNXBJTpXbkI5rPWNy3p'},
#     'href': 'https://api.spotify.com/v1/tracks/0NWqNXBJTpXbkI5rPWNy3p',
#     'id': '0NWqNXBJTpXbkI5rPWNy3p',
#     'is_local': False,
#     'name': 'All I Know',
#     'preview_url': None,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:0NWqNXBJTpXbkI5rPWNy3p'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260253,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Ch7LmS7r2Gy2kc64wv3Bz'},
#     'href': 'https://api.spotify.com/v1/tracks/2Ch7LmS7r2Gy2kc64wv3Bz',
#     'id': '2Ch7LmS7r2Gy2kc64wv3Bz',
#     'is_local': False,
#     'name': 'Die For You',
#     'preview_url': None,
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:2Ch7LmS7r2Gy2kc64wv3Bz'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 269186,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dhjNA0jGA8vHBQ1VdD6vV'},
#     'href': 'https://api.spotify.com/v1/tracks/3dhjNA0jGA8vHBQ1VdD6vV',
#     'id': '3dhjNA0jGA8vHBQ1VdD6vV',
#     'is_local': False,
#     'name': 'I Feel It Coming',
#     'preview_url': None,
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:3dhjNA0jGA8vHBQ1VdD6vV'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 18},
#  'type': 'album',
#  'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'}
