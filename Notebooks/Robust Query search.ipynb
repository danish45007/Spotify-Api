# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

# %% [markdown]
# # Client_Id and Client_Secret

# %%
client_id = 'a91b43299c1640f0aa948cec94a6f6fe'
client_secret = 'dcb87c21bfaa4644b7fff077bb29c129'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expires = True
    
    client_id = None
    client_secret = None
    token_url = " https://accounts.spotify.com/api/token"
    
    def __init__(self,client_id,client_secret,*args,**kwargs):
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns: a Base 64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client_Id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
        
    def get_token_header(self):
        client_creds_b64 = self.get_client_credentials()
        
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
        
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }

    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_header()
        req = requests.post(token_url, data=token_data, headers=token_headers)
        if req.status_code not in range(200,299):
             raise Exception("could not Authenticate the client")
        
        data = req.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expires = expires < now
        return True
    
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires<now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
     
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization" : f"Bearer {access_token}" 
        }
        return headers
    
    def get_resource(self,lookup_id,resource_type = 'albums',version='v1'):
        endpoint = f" https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

        
            
    def get_album(self,_id):
        return self.get_resource(_id,resource_type='albums')

    def get_artists(self,_id):
        return self.get_resource(_id,resource_type='artists')
        
    
    def base_search(self, query_params):
        headers = self.get_resource_header()
        endpoint = " https://api.spotify.com/v1/search"
        look_url = f"{endpoint}?{query_params}"
        print(look_url)
        r = requests.get(look_url, headers = headers)
        if r.status_code not in range(200, 299):
            return {}
        
        return r.json()
    
    def search(self,query=None,operator=None, operator_query=None, search_type = "artist"):
        if query==None:
            raise Exception("A query is required")
        if isinstance(query,dict):
            
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query,str):
                    query = f"{query} {operator} {operator_query}"
            
        query_params = urlencode({"q": query, "type": search_type.lower()})
        return self.base_search(query_params)

# %%
#spotify.get_access_token()

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search({"track" :"Starboy"},search_type="track")
# Out:
#  https://api.spotify.com/v1/search?q=track%3AStarboy&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AStarboy&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#      'href': 'https://api.spotify.com/v1/albums/2ODvWsOgouMbaA5xf0RkJe',
#      'id': '2ODvWsOgouMbaA5xf0RkJe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734718e2b124f79258be7bc452',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024718e2b124f79258be7bc452',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:2ODvWsOgouMbaA5xf0RkJe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230453,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11600976'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB'},
#     'href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#     'id': '7MXVkk9YMctZqd1Srtv4MB',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 85,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4rGQxBDZ4hHCKePXaYOTSB'},
#      'href': 'https://api.spotify.com/v1/albums/4rGQxBDZ4hHCKePXaYOTSB',
#      'id': '4rGQxBDZ4hHCKePXaYOTSB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2148749eb6478e176b3f93c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2148749eb6478e176b3f93c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2148749eb6478e176b3f93c',
#        'width': 64}],
#      'name': 'Starboy (Kygo Remix)',
#      'release_date': '2016-11-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4rGQxBDZ4hHCKePXaYOTSB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#       'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#       'id': '23fqKkggKUBHNkbKtXEls4',
#       'name': 'Kygo',
#       'type': 'artist',
#       'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244720,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11601353'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6LJFgCd9wU2VptHEwz2Wl3'},
#     'href': 'https://api.spotify.com/v1/tracks/6LJFgCd9wU2VptHEwz2Wl3',
#     'id': '6LJFgCd9wU2VptHEwz2Wl3',
#     'is_local': False,
#     'name': 'Starboy - Kygo Remix',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6LJFgCd9wU2VptHEwz2Wl3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AE',
#       'AU',
#       'BH',
#       'CA',
#       'DZ',
#       'EG',
#       'GB',
#       'ID',
#       'IE',
#       'IN',
#       'JO',
#       'KW',
#       'LB',
#       'MA',
#       'MY',
#       'OM',
#       'PS',
#       'QA',
#       'SA',
#       'TN',
#       'TR',
#       'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#      'href': 'https://api.spotify.com/v1/albums/4AdZV63ycxFLF6Hcol0QnB',
#      'id': '4AdZV63ycxFLF6Hcol0QnB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a048415db06a5b6fa7ec4e1a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a048415db06a5b6fa7ec4e1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a048415db06a5b6fa7ec4e1a',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4AdZV63ycxFLF6Hcol0QnB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AE',
#      'AU',
#      'BH',
#      'CA',
#      'DZ',
#      'EG',
#      'GB',
#      'ID',
#      'IE',
#      'IN',
#      'JO',
#      'KW',
#      'LB',
#      'MA',
#      'MY',
#      'OM',
#      'PS',
#      'QA',
#      'SA',
#      'TN',
#      'TR',
#      'US'],
#     'disc_number': 1,
#     'duration_ms': 230453,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11600977'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7HtPBwBoCBDy1tpstag7HL'},
#     'href': 'https://api.spotify.com/v1/tracks/7HtPBwBoCBDy1tpstag7HL',
#     'id': '7HtPBwBoCBDy1tpstag7HL',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 52,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7HtPBwBoCBDy1tpstag7HL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hyAYqBdxyramm4W9TB7R0'},
#        'href': 'https://api.spotify.com/v1/artists/6hyAYqBdxyramm4W9TB7R0',
#        'id': '6hyAYqBdxyramm4W9TB7R0',
#        'name': 'The Animal In Me',
#        'type': 'artist',
#        'uri': 'spotify:artist:6hyAYqBdxyramm4W9TB7R0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5raf9Agi3ferPfy54ucXLH'},
#      'href': 'https://api.spotify.com/v1/albums/5raf9Agi3ferPfy54ucXLH',
#      'id': '5raf9Agi3ferPfy54ucXLH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736339c72394e2568c811ebccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026339c72394e2568c811ebccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516339c72394e2568c811ebccd',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2017-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5raf9Agi3ferPfy54ucXLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hyAYqBdxyramm4W9TB7R0'},
#       'href': 'https://api.spotify.com/v1/artists/6hyAYqBdxyramm4W9TB7R0',
#       'id': '6hyAYqBdxyramm4W9TB7R0',
#       'name': 'The Animal In Me',
#       'type': 'artist',
#       'uri': 'spotify:artist:6hyAYqBdxyramm4W9TB7R0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 246362,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ22B1763574'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4LceuFIJXzhCJ9iJsYmf0f'},
#     'href': 'https://api.spotify.com/v1/tracks/4LceuFIJXzhCJ9iJsYmf0f',
#     'id': '4LceuFIJXzhCJ9iJsYmf0f',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9634cb73bfade10fb85590eab97be2c235e1c4a7?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4LceuFIJXzhCJ9iJsYmf0f'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KwmxIhSe9UTSEF37kwngR'},
#        'href': 'https://api.spotify.com/v1/artists/3KwmxIhSe9UTSEF37kwngR',
#        'id': '3KwmxIhSe9UTSEF37kwngR',
#        'name': 'SHAED',
#        'type': 'artist',
#        'uri': 'spotify:artist:3KwmxIhSe9UTSEF37kwngR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7422NfmOW8GffdVQNbM90S'},
#      'href': 'https://api.spotify.com/v1/albums/7422NfmOW8GffdVQNbM90S',
#      'id': '7422NfmOW8GffdVQNbM90S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273369a5fb7be1d112246988433',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02369a5fb7be1d112246988433',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851369a5fb7be1d112246988433',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2016-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7422NfmOW8GffdVQNbM90S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KwmxIhSe9UTSEF37kwngR'},
#       'href': 'https://api.spotify.com/v1/artists/3KwmxIhSe9UTSEF37kwngR',
#       'id': '3KwmxIhSe9UTSEF37kwngR',
#       'name': 'SHAED',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KwmxIhSe9UTSEF37kwngR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211173,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZ47A1600208'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7FxWJX9m6V4d9lYZ5vogqW'},
#     'href': 'https://api.spotify.com/v1/tracks/7FxWJX9m6V4d9lYZ5vogqW',
#     'id': '7FxWJX9m6V4d9lYZ5vogqW',
#     'is_local': False,
#     'name': 'Starboy - Recorded at Spotify Studios NYC',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7FxWJX9m6V4d9lYZ5vogqW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42PbLkrI8H7k1kqOU3wnmN'},
#        'href': 'https://api.spotify.com/v1/artists/42PbLkrI8H7k1kqOU3wnmN',
#        'id': '42PbLkrI8H7k1kqOU3wnmN',
#        'name': 'TyBuckz',
#        'type': 'artist',
#        'uri': 'spotify:artist:42PbLkrI8H7k1kqOU3wnmN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6NPfRhMgn6KIH6PePIEX2Y'},
#      'href': 'https://api.spotify.com/v1/albums/6NPfRhMgn6KIH6PePIEX2Y',
#      'id': '6NPfRhMgn6KIH6PePIEX2Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739525683bb621aabf399d6ac8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029525683bb621aabf399d6ac8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519525683bb621aabf399d6ac8',
#        'width': 64}],
#      'name': 'Starboy Pack',
#      'release_date': '2020-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:6NPfRhMgn6KIH6PePIEX2Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/42PbLkrI8H7k1kqOU3wnmN'},
#       'href': 'https://api.spotify.com/v1/artists/42PbLkrI8H7k1kqOU3wnmN',
#       'id': '42PbLkrI8H7k1kqOU3wnmN',
#       'name': 'TyBuckz',
#       'type': 'artist',
#       'uri': 'spotify:artist:42PbLkrI8H7k1kqOU3wnmN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 107728,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZDA62032950'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6kC29mbkeRPP0odWTEJ4x4'},
#     'href': 'https://api.spotify.com/v1/tracks/6kC29mbkeRPP0odWTEJ4x4',
#     'id': '6kC29mbkeRPP0odWTEJ4x4',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/05644a4a77886cd13a1483c8bc4c1cb40d918cf9?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6kC29mbkeRPP0odWTEJ4x4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DRnjvzNP8pk868AvG5Kpd'},
#        'href': 'https://api.spotify.com/v1/artists/4DRnjvzNP8pk868AvG5Kpd',
#        'id': '4DRnjvzNP8pk868AvG5Kpd',
#        'name': 'RPM (Relaxing Piano Music)',
#        'type': 'artist',
#        'uri': 'spotify:artist:4DRnjvzNP8pk868AvG5Kpd'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ZE6huGctIo5v1wWRjxAVg'},
#      'href': 'https://api.spotify.com/v1/albums/4ZE6huGctIo5v1wWRjxAVg',
#      'id': '4ZE6huGctIo5v1wWRjxAVg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fb6fdd725d54fe511f7f34fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fb6fdd725d54fe511f7f34fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fb6fdd725d54fe511f7f34fb',
#        'width': 64}],
#      'name': 'RPM (Relaxing Piano Music)',
#      'release_date': '2019-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4ZE6huGctIo5v1wWRjxAVg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4DRnjvzNP8pk868AvG5Kpd'},
#       'href': 'https://api.spotify.com/v1/artists/4DRnjvzNP8pk868AvG5Kpd',
#       'id': '4DRnjvzNP8pk868AvG5Kpd',
#       'name': 'RPM (Relaxing Piano Music)',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DRnjvzNP8pk868AvG5Kpd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 239693,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEBGA1700089'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3IZPbpm7bAcgiE8lwoyCEB'},
#     'href': 'https://api.spotify.com/v1/tracks/3IZPbpm7bAcgiE8lwoyCEB',
#     'id': '3IZPbpm7bAcgiE8lwoyCEB',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/54e5baa5db6ea359f498dffa2dfa6e526d4b0ab6?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3IZPbpm7bAcgiE8lwoyCEB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EqB7cUIzAytMt9vCYfALQ'},
#        'href': 'https://api.spotify.com/v1/artists/4EqB7cUIzAytMt9vCYfALQ',
#        'id': '4EqB7cUIzAytMt9vCYfALQ',
#        'name': 'Niko Kotoulas',
#        'type': 'artist',
#        'uri': 'spotify:artist:4EqB7cUIzAytMt9vCYfALQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3hD5oerLYMOU4HUytRUt3W'},
#      'href': 'https://api.spotify.com/v1/albums/3hD5oerLYMOU4HUytRUt3W',
#      'id': '3hD5oerLYMOU4HUytRUt3W',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739056eda6d89f8827a79fc5e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029056eda6d89f8827a79fc5e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519056eda6d89f8827a79fc5e2',
#        'width': 64}],
#      'name': 'Piano Covers, Vol 6: Starboy',
#      'release_date': '2016-12-17',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:3hD5oerLYMOU4HUytRUt3W'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EqB7cUIzAytMt9vCYfALQ'},
#       'href': 'https://api.spotify.com/v1/artists/4EqB7cUIzAytMt9vCYfALQ',
#       'id': '4EqB7cUIzAytMt9vCYfALQ',
#       'name': 'Niko Kotoulas',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EqB7cUIzAytMt9vCYfALQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 252187,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ22B1636308'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3NJ78AkgbEcYLxdzQnSe7N'},
#     'href': 'https://api.spotify.com/v1/tracks/3NJ78AkgbEcYLxdzQnSe7N',
#     'id': '3NJ78AkgbEcYLxdzQnSe7N',
#     'is_local': False,
#     'name': 'Starboy - Piano Arrangement',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c5a75fcc3e9c6e865d464694c65bc47a7e35d5e7?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3NJ78AkgbEcYLxdzQnSe7N'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4yZSvg16XY22sxvZzKfw'},
#        'href': 'https://api.spotify.com/v1/artists/7n4yZSvg16XY22sxvZzKfw',
#        'id': '7n4yZSvg16XY22sxvZzKfw',
#        'name': 'Simon Samaeng',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n4yZSvg16XY22sxvZzKfw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Bh0yujzOhMqly3ONkprWR'},
#      'href': 'https://api.spotify.com/v1/albums/5Bh0yujzOhMqly3ONkprWR',
#      'id': '5Bh0yujzOhMqly3ONkprWR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d4129a6795ffb602cd79ffd2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d4129a6795ffb602cd79ffd2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d4129a6795ffb602cd79ffd2',
#        'width': 64}],
#      'name': 'Starboy (Acoustic)',
#      'release_date': '2016-12-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5Bh0yujzOhMqly3ONkprWR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4yZSvg16XY22sxvZzKfw'},
#       'href': 'https://api.spotify.com/v1/artists/7n4yZSvg16XY22sxvZzKfw',
#       'id': '7n4yZSvg16XY22sxvZzKfw',
#       'name': 'Simon Samaeng',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n4yZSvg16XY22sxvZzKfw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 225790,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1600514'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2QoyYV4YAuw9T9UgsDoam2'},
#     'href': 'https://api.spotify.com/v1/tracks/2QoyYV4YAuw9T9UgsDoam2',
#     'id': '2QoyYV4YAuw9T9UgsDoam2',
#     'is_local': False,
#     'name': 'Starboy - Acoustic',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/670ed08513d8d23a5756745b58be00781a49361b?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2QoyYV4YAuw9T9UgsDoam2'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19ZAQw6Iah26CVL8jxprAQ'},
#      'href': 'https://api.spotify.com/v1/albums/19ZAQw6Iah26CVL8jxprAQ',
#      'id': '19ZAQw6Iah26CVL8jxprAQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27320ba0e47a2bf48de07ac88d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0220ba0e47a2bf48de07ac88d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485120ba0e47a2bf48de07ac88d0',
#        'width': 64}],
#      'name': "NOW That's What I Call Music, Vol. 61",
#      'release_date': '2017-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:19ZAQw6Iah26CVL8jxprAQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 227826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11600977'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4rJKRx0NtEN0mQQrFLXYWY'},
#     'href': 'https://api.spotify.com/v1/tracks/4rJKRx0NtEN0mQQrFLXYWY',
#     'id': '4rJKRx0NtEN0mQQrFLXYWY',
#     'is_local': False,
#     'name': 'Starboy (feat. Daft Punk)',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5d289e72dc6d3f58666bae7ca32ba2936ce00efa?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4rJKRx0NtEN0mQQrFLXYWY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#        'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#        'id': '6MERXsiRbur2oJZFgYRDKz',
#        'name': 'Vitamin String Quartet',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/42uXnfr69zoPYoudG0wBNc'},
#      'href': 'https://api.spotify.com/v1/albums/42uXnfr69zoPYoudG0wBNc',
#      'id': '42uXnfr69zoPYoudG0wBNc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738b6952a390a28e52a75adacf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028b6952a390a28e52a75adacf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518b6952a390a28e52a75adacf',
#        'width': 64}],
#      'name': 'VSQ Performs the Weeknd',
#      'release_date': '2017-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:42uXnfr69zoPYoudG0wBNc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#       'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#       'id': '6MERXsiRbur2oJZFgYRDKz',
#       'name': 'Vitamin String Quartet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1790148'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3hdZnjc5VQwjQiePLh0Q99'},
#     'href': 'https://api.spotify.com/v1/tracks/3hdZnjc5VQwjQiePLh0Q99',
#     'id': '3hdZnjc5VQwjQiePLh0Q99',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2399a9e70b5c83c5d1a297d596a57ddb36d3adca?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3hdZnjc5VQwjQiePLh0Q99'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pcymMubKlBFQ1H7gXzYmL'},
#        'href': 'https://api.spotify.com/v1/artists/6pcymMubKlBFQ1H7gXzYmL',
#        'id': '6pcymMubKlBFQ1H7gXzYmL',
#        'name': 'Secret Eyes',
#        'type': 'artist',
#        'uri': 'spotify:artist:6pcymMubKlBFQ1H7gXzYmL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ne4p2FLfmjhkrMc54qyjq'},
#      'href': 'https://api.spotify.com/v1/albums/4ne4p2FLfmjhkrMc54qyjq',
#      'id': '4ne4p2FLfmjhkrMc54qyjq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb787c301932aa6fe80cb811',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb787c301932aa6fe80cb811',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb787c301932aa6fe80cb811',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2017-03-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4ne4p2FLfmjhkrMc54qyjq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pcymMubKlBFQ1H7gXzYmL'},
#       'href': 'https://api.spotify.com/v1/artists/6pcymMubKlBFQ1H7gXzYmL',
#       'id': '6pcymMubKlBFQ1H7gXzYmL',
#       'name': 'Secret Eyes',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pcymMubKlBFQ1H7gXzYmL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231895,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACY1758454'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4REfifrG2fa6ra3DQ6laGE'},
#     'href': 'https://api.spotify.com/v1/tracks/4REfifrG2fa6ra3DQ6laGE',
#     'id': '4REfifrG2fa6ra3DQ6laGE',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8e44f9e6b82aa3e458b7caed086c5d2dd31daa90?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4REfifrG2fa6ra3DQ6laGE'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AE',
#       'BH',
#       'CA',
#       'DZ',
#       'EG',
#       'GB',
#       'ID',
#       'IE',
#       'IN',
#       'JO',
#       'KW',
#       'LB',
#       'MA',
#       'MX',
#       'MY',
#       'OM',
#       'PS',
#       'QA',
#       'SA',
#       'TN',
#       'TR',
#       'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7ixcPZPdSRkl5qjhoWM6Xh'},
#      'href': 'https://api.spotify.com/v1/albums/7ixcPZPdSRkl5qjhoWM6Xh',
#      'id': '7ixcPZPdSRkl5qjhoWM6Xh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c2fac87d1c006e4596d77ea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c2fac87d1c006e4596d77ea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c2fac87d1c006e4596d77ea',
#        'width': 64}],
#      'name': 'Starboy (Kygo Remix)',
#      'release_date': '2016-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7ixcPZPdSRkl5qjhoWM6Xh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
# ...
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7KTpcqL8e0cikkPrR51UQi'},
#      'href': 'https://api.spotify.com/v1/albums/7KTpcqL8e0cikkPrR51UQi',
#      'id': '7KTpcqL8e0cikkPrR51UQi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ceff9f03312332dd80fa02f3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ceff9f03312332dd80fa02f3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ceff9f03312332dd80fa02f3',
#        'width': 64}],
#      'name': 'Starboy',
#      'release_date': '2016-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7KTpcqL8e0cikkPrR51UQi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eDKMXn3OBIkI8jcY7JtlI'},
#       'href': 'https://api.spotify.com/v1/artists/6eDKMXn3OBIkI8jcY7JtlI',
#       'id': '6eDKMXn3OBIkI8jcY7JtlI',
#       'name': 'ESPRIT 空想',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eDKMXn3OBIkI8jcY7JtlI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 111818,
#     'explicit': False,
#     'external_ids': {'isrc': 'UST8K1641746'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45a1zIGXYNvIMA7vu7krdO'},
#     'href': 'https://api.spotify.com/v1/tracks/45a1zIGXYNvIMA7vu7krdO',
#     'id': '45a1zIGXYNvIMA7vu7krdO',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b96d2aaf73c9c153604b428cf5eb2c68f54ba84?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:45a1zIGXYNvIMA7vu7krdO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4yZSvg16XY22sxvZzKfw'},
#        'href': 'https://api.spotify.com/v1/artists/7n4yZSvg16XY22sxvZzKfw',
#        'id': '7n4yZSvg16XY22sxvZzKfw',
#        'name': 'Simon Samaeng',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n4yZSvg16XY22sxvZzKfw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4M8fbzOmA9eMiGwfifB5y0'},
#      'href': 'https://api.spotify.com/v1/albums/4M8fbzOmA9eMiGwfifB5y0',
#      'id': '4M8fbzOmA9eMiGwfifB5y0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27383c89b9c0735f23a5edbce1d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0283c89b9c0735f23a5edbce1d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485183c89b9c0735f23a5edbce1d',
#        'width': 64}],
#      'name': 'The Covers',
#      'release_date': '2019-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4M8fbzOmA9eMiGwfifB5y0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4yZSvg16XY22sxvZzKfw'},
#       'href': 'https://api.spotify.com/v1/artists/7n4yZSvg16XY22sxvZzKfw',
#       'id': '7n4yZSvg16XY22sxvZzKfw',
#       'name': 'Simon Samaeng',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n4yZSvg16XY22sxvZzKfw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 225790,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1600514'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0RjoMXAC8TnGhiUvEz6xtC'},
#     'href': 'https://api.spotify.com/v1/tracks/0RjoMXAC8TnGhiUvEz6xtC',
#     'id': '0RjoMXAC8TnGhiUvEz6xtC',
#     'is_local': False,
#     'name': 'Starboy - Acoustic',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/670ed08513d8d23a5756745b58be00781a49361b?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0RjoMXAC8TnGhiUvEz6xtC'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BETdCqKlraxPwjzH4JUIB'},
#        'href': 'https://api.spotify.com/v1/artists/3BETdCqKlraxPwjzH4JUIB',
#        'id': '3BETdCqKlraxPwjzH4JUIB',
#        'name': 'Koni',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BETdCqKlraxPwjzH4JUIB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14mpQlt5S1JOJBk73SLVAx'},
#      'href': 'https://api.spotify.com/v1/albums/14mpQlt5S1JOJBk73SLVAx',
#      'id': '14mpQlt5S1JOJBk73SLVAx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273703550239a9e5168b6dd3740',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02703550239a9e5168b6dd3740',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851703550239a9e5168b6dd3740',
#        'width': 64}],
#      'name': 'Starboy (feat. Johannes Weber)',
#      'release_date': '2016-10-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:14mpQlt5S1JOJBk73SLVAx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BETdCqKlraxPwjzH4JUIB'},
#       'href': 'https://api.spotify.com/v1/artists/3BETdCqKlraxPwjzH4JUIB',
#       'id': '3BETdCqKlraxPwjzH4JUIB',
#       'name': 'Koni',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BETdCqKlraxPwjzH4JUIB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Z2NI874Tk9DX2sK2odGV3'},
#       'href': 'https://api.spotify.com/v1/artists/1Z2NI874Tk9DX2sK2odGV3',
#       'id': '1Z2NI874Tk9DX2sK2odGV3',
#       'name': 'Johannes Weber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Z2NI874Tk9DX2sK2odGV3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243069,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB-SMU-30-58451'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4PIu30DABi4r407Pxnmy0P'},
#     'href': 'https://api.spotify.com/v1/tracks/4PIu30DABi4r407Pxnmy0P',
#     'id': '4PIu30DABi4r407Pxnmy0P',
#     'is_local': False,
#     'name': 'Starboy (feat. Johannes Weber)',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/06eb5297d7c2b065bef8558b8e8713ed52cf1e54?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4PIu30DABi4r407Pxnmy0P'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5kx3yVKDx55iEMTsgoMrud'},
#      'href': 'https://api.spotify.com/v1/albums/5kx3yVKDx55iEMTsgoMrud',
#      'id': '5kx3yVKDx55iEMTsgoMrud',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273337d016a589221b6302237fe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02337d016a589221b6302237fe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851337d016a589221b6302237fe',
#        'width': 64}],
#      'name': 'Acoustic Covers: The Album',
#      'release_date': '2017-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:5kx3yVKDx55iEMTsgoMrud'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5vZ5k7ySgoaLpLdZB98nfo'},
#       'href': 'https://api.spotify.com/v1/artists/5vZ5k7ySgoaLpLdZB98nfo',
#       'id': '5vZ5k7ySgoaLpLdZB98nfo',
#       'name': 'Rajiv Dhall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5vZ5k7ySgoaLpLdZB98nfo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 127951,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACY1747077'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3fLdKcXilUEjU67YNCeI7s'},
#     'href': 'https://api.spotify.com/v1/tracks/3fLdKcXilUEjU67YNCeI7s',
#     'id': '3fLdKcXilUEjU67YNCeI7s',
#     'is_local': False,
#     'name': 'Starboy',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d9c1016cb2ebec4237d38224201bc4006efe17a?cid=a91b43299c1640f0aa948cec94a6f6fe',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3fLdKcXilUEjU67YNCeI7s'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3AStarboy&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 763}}

# %%
#spotify.get_artists(_id="1Xyo4u8uXC1ZmMpatF05PJ")

# %%
#spotify.get_album(_id="2ODvWsOgouMbaA5xf0RkJe")

# %%
spotify.search(query="Danger",operator="NOT","",search_type="track")
